# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import warnings
warnings.simplefilter("ignore") # 무시할게

sns.set_theme()
sns.set(rc={"figure.figsize":(12,8)})

plt.rcParams["font.family"] = "Apple SD Gothic Neo"
plt.rcParams["axes.unicode_minus"] = False

# %%
movie_title = ["크루엘라","극장판 귀멸의 칼날 : 무한열차편","학교 가는 길"]
audience = [664308,2099131,20067]

df = pd.DataFrame({
    "영화제목":movie_title,
    "누적관객":audience
})
df
# Out:
#                  영화제목     누적관객
# 0                크루엘라   664308
# 1  극장판 귀멸의 칼날 : 무한열차편  2099131
# 2             학교 가는 길    20067

# %%
sns.barplot(data=df, x="영화제목", y="누적관객")
# Out:
# <Axes: xlabel='영화제목', ylabel='누적관객'>

# %%
sns.barplot(data=df, x="영화제목", y="누적관객", order=df.sort_values("누적관객").영화제목)
# Out:
# <Axes: xlabel='영화제목', ylabel='누적관객'>

# %%
sns.barplot(data=df, x="영화제목", y="누적관객", order=df.sort_values("누적관객",ascending=False).영화제목)
# Out:
# <Axes: xlabel='영화제목', ylabel='누적관객'>

# %%
g = sns.barplot(data=df, x="영화제목", y="누적관객", order=df.sort_values("누적관객",ascending=False).영화제목)

label_format = "{:,.0f}"

ylabels = [label_format.format(i)+"만 명"for i in g.get_yticks() / 10000]
g.set_yticklabels(ylabels)
# Out:
# [Text(0, 0.0, '0만 명'),
#  Text(0, 250000.0, '25만 명'),
#  Text(0, 500000.0, '50만 명'),
#  Text(0, 750000.0, '75만 명'),
#  Text(0, 1000000.0, '100만 명'),
#  Text(0, 1250000.0, '125만 명'),
#  Text(0, 1500000.0, '150만 명'),
#  Text(0, 1750000.0, '175만 명'),
#  Text(0, 2000000.0, '200만 명'),
#  Text(0, 2250000.0, '225만 명')]

# %%
df = sns.load_dataset("flights")
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# 신뢰구간 : 95
g = sns.lineplot(data=df, x="year", y="passengers")

# %%
g = sns.lineplot(data=df, x="year", y="passengers")
plt.xticks(df['year']); # ; : 차트 그릴 때 나오는 문자열 제거

# %%
# hue : 그룹화
g = sns.lineplot(data=df, x="year", y="passengers", hue="month")

# %%
g = sns.lineplot(data=df, x="year", y="passengers", hue="month", style="month")

# %%
g = sns.lineplot(data=df, x="year", y="passengers", hue="month", style="month", markers=True)

# %%
iris = sns.load_dataset("iris")

# %%
sns.boxplot(data=iris)
# Out:
# <Axes: >

# %%
sns.boxplot(data=iris, orient="h")
# Out:
# <Axes: >

# %%
sns.swarmplot(data=iris)
# Out:
# <Axes: >

# %%
sns.violinplot(data=iris)
# Out:
# <Axes: >

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# 성별 차트 작성
titanic.groupby(by="sex")["sex"].count()
# Out:
# sex
# female    314
# male      577
# Name: sex, dtype: int64

# %%
titanic.groupby(by="sex")["sex"].count().sort_index(ascending=False).plot.bar() # ascending=False : 알파벳순
# Out:
# <Axes: xlabel='sex'>

# %%
sns.countplot(data=titanic,x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# 성별 인원수를 객실 등급별로 시각화
g = sns.countplot(data=titanic,x="sex",hue="class")
